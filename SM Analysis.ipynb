# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\DELL\Downloads\Seminar\Survey\Social_Media_Usage_Survey.csv')

# %%
df.head()
# Out:
#                       Timestamp  \
# 0  2020/11/17 11:52:18 am GMT+4
# 1  2020/11/17 11:53:35 am GMT+4
# 2  2020/11/17 12:00:14 pm GMT+4
# 3  2020/11/17 12:02:09 pm GMT+4
# 4  2020/11/17 12:07:27 pm GMT+4
#
#   Name as initials (e.g. LN for Lakshmi Narayanan )              Age  Gender  \
# 0                                                LN            18-24  Female
# 1                                                VR  Greater than 40  Female
# 2                                               KKB  Greater than 40    Male
# 3                                                RS            30-40    Male
# 4                                             Bibin            30-40    Male
#
#   Do you use a smartphone? Do you use social media (SM)?  \
# 0                      Yes                           Yes
# 1                      Yes                           Yes
# 2                      Yes                           Yes
# 3                      Yes                           Yes
# ...

# %%
df.shape
# Out:
# (102, 25)

# %%
df['Age'].value_counts()
# Out:
# 18-24              41
# Greater than 40    37
# 30-40              21
# 25-30               3
# Name: Age, dtype: int64

# %%
df['Age'].value_counts(normalize=True)
# Out:
# 18-24              0.401961
# Greater than 40    0.362745
# 30-40              0.205882
# 25-30              0.029412
# Name: Age, dtype: float64

# %%
# %matplotlib inline

# %%
df['Which is your favorite social media platform?'].value_counts().plot(kind='bar', figsize=(15,7), color="#61d199")

# %%
filtered_1 = df[(df['Which is your favorite social media platform?'] == 'Instagram') & (df['How many hours on average in a day do you spend on social media?'] == 'Greater than 4 hours')]

# %%
print(filtered_1['Which is your favorite social media platform?'].value_counts())
print(filtered_1['How many hours on average in a day do you spend on social media?'].value_counts())
# Out:
# Instagram    8
# Name: Which is your favorite social media platform?, dtype: int64
# Greater than 4 hours    8
# Name: How many hours on average in a day do you spend on social media?, dtype: int64

# %%
filtered_2 = df[(df['Which social media platform do you use? (You can choose more than one option)'].str.contains('Instagram')) & (df['How many hours on average in a day do you spend on social media?'] == 'Greater than 4 hours')]

# %%
filtered_2
# Out:
#                        Timestamp  \
# 0   2020/11/17 11:52:18 am GMT+4
# 6   2020/11/17 12:10:32 pm GMT+4
# 10  2020/11/17 12:15:36 pm GMT+4
# 11  2020/11/17 12:23:59 pm GMT+4
# 12  2020/11/17 12:31:20 pm GMT+4
# 15  2020/11/17 12:40:55 pm GMT+4
# 18  2020/11/17 12:45:44 pm GMT+4
# 27   2020/11/17 3:38:25 pm GMT+4
# 30   2020/11/17 4:00:36 pm GMT+4
# 31   2020/11/17 4:16:37 pm GMT+4
# 32   2020/11/17 4:38:10 pm GMT+4
# 33   2020/11/17 4:40:12 pm GMT+4
# 35   2020/11/17 5:10:06 pm GMT+4
# 38   2020/11/17 5:21:56 pm GMT+4
# 45   2020/11/17 6:45:42 pm GMT+4
# 46   2020/11/17 6:53:09 pm GMT+4
# 50  2020/11/17 10:28:42 pm GMT+4
# 65   2020/11/19 4:05:37 pm GMT+4
#
#    Name as initials (e.g. LN for Lakshmi Narayanan )    Age  Gender  \
# 0                                                 LN  18-24  Female
# 6                                                 AX  18-24    Male
# 10                                                DP  25-30  Female
# ...

# %%
print(filtered_2['How many hours on average in a day do you spend on social media?'].value_counts())
# Out:
# Greater than 4 hours    18
# Name: How many hours on average in a day do you spend on social media?, dtype: int64

# %%
sm_lists = df["Which social media platform do you use? (You can choose more than one option)"].str.split(';', expand=True)
sm_lists.head()
# Out:
#            0          1         2         3         4        5     6
# 0   Facebook  Instagram  LinkedIn  Snapchat  WhatsApp  YouTube  None
# 1   Facebook   LinkedIn  WhatsApp   YouTube      None     None  None
# 2   Facebook  Instagram  WhatsApp      None      None     None  None
# 3  Instagram   WhatsApp   YouTube      None      None     None  None
# 4   Facebook   WhatsApp   YouTube      None      None     None  None

# %%
sm_lists.stack()
# Out:
# 0    0     Facebook
#      1    Instagram
#      2     LinkedIn
#      3     Snapchat
#      4     WhatsApp
#             ...
# 100  1    Instagram
#      2     WhatsApp
#      3      YouTube
# 101  0     WhatsApp
#      1      YouTube
# Length: 428, dtype: object

# %%
sm_lists.stack().value_counts()
# Out:
# WhatsApp     101
# YouTube       94
# Facebook      70
# Instagram     67
# LinkedIn      47
# Snapchat      26
# Twitter       15
# Tiktok         8
# dtype: int64

# %%
sm_lists.stack().value_counts().plot(kind='bar', figsize=(15,7), color="#61d199")

# %%
df['Age'].value_counts().plot(kind='bar', figsize=(15,7), color="#61d199")

# %%
df['How many hours on average in a day do you spend on social media?'].value_counts().plot(kind='bar', figsize=(15,7), color="#61d199")

# %%
import matplotlib.pyplot as plt

labels = ['1-2 hrs', '2-4 hrs', '>4 hrs', '<1 hr']
sizes = df['How many hours on average in a day do you spend on social media?'].value_counts()

explode = (0.2,0.2,0.2,0.2)
colors = ["#61D199","#857E7B","#FCD757","#FBBA72"]

fig1, ax1 = plt.subplots()

ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90, colors=colors, pctdistance=0.85)
ax1.axis('equal')

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)


plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['1-2 hrs', '2-4 hrs', '>4 hrs', '<1 hr']
sizes = df['How many hours on average in a day do you spend on social media?'].value_counts()

labels_prod = ['Agree','Disagree','Neutral','Strongly disagree','Strongly agree','Agree','Disagree','Neutral','Strongly disagree','Strongly agree','Agree','Disagree','Neutral','Strongly disagree','Strongly agree','Agree','Disagree','Neutral','Strongly disagree','Strongly agree']
sizes_prod = df['I notice that my productivity has diminished due to social media.'].value_counts()

colors = ["#61D199","#857E7B","#FCD757","#FBBA72"]
colors_prod = ["#ED9390","#B5E2FA","#5B6057","#EDDEA4","#EFBCD5"]

fig1, ax1 = plt.subplots()

ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90, colors=colors, pctdistance=0.9, frame=True)
ax1.pie(sizes_prod, autopct='%1.1f%%',radius=0.75,
        shadow=False, startangle=90, colors=colors_prod, pctdistance=0.5)
ax1.axis('equal')

centre_circle = plt.Circle((0,0),0.40,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)


plt.tight_layout()
plt.show()

# %%
df['I notice that my productivity has diminished due to social media.'].value_counts()
# Out:
# Agree                30
# Disagree             30
# Neutral              20
# Strongly disagree    13
# Strongly agree        8
# Name: I notice that my productivity has diminished due to social media., dtype: int64

# %%
df['I notice that my productivity has diminished due to social media.'].value_counts().plot(kind='bar', figsize=(15,7), color="#61d199")

# %%
filtered_3 = df[(df['I notice that my productivity has diminished due to social media.'] =='Agree') & (df['How many hours on average in a day do you spend on social media?'] == 'Greater than 4 hours')]

# %%
print(filtered_3['How many hours on average in a day do you spend on social media?'].value_counts())
# Out:
# Greater than 4 hours    8
# Name: How many hours on average in a day do you spend on social media?, dtype: int64

# %%
df['I feel unhappy and missing out when I am not on social media.'].value_counts().plot(kind='bar', figsize=(15,7), color="#61d199")

# %%
df['I spend time on social media when I am alone.'].value_counts().plot(kind='bar', figsize=(15,7), color="#61d199")

# %%
use_lists = df["What is the purpose of using social media? (You can choose more than one option)"].str.split(';', expand=True)
use_lists.head()
# Out:
#                                      0                               1  \
# 0             Learning new information  Sharing and posting daily life
# 1             Learning new information  Sharing and posting daily life
# 2  Interacting with family and friends                            None
# 3             Learning new information                   Entertainment
# 4             Learning new information                   Entertainment
#
#                                      2              3  \
# 0  Interacting with family and friends  Entertainment
# 1  Interacting with family and friends           None
# 2                                 None           None
# 3                                 None           None
# 4                             Shopping           None
#
#                           4     5
# 0  Surfing and passing time  None
# 1                      None  None
# 2                      None  None
# 3                      None  None
# 4                      None  None

# %%
use_lists.stack()
# Out:
# 0    0               Learning new information
#      1         Sharing and posting daily life
#      2    Interacting with family and friends
#      3                          Entertainment
#      4               Surfing and passing time
#                          ...
# 100  0               Learning new information
# 101  0               Learning new information
#      1    Interacting with family and friends
#      2                          Entertainment
#      3                               Shopping
# Length: 302, dtype: object

# %%
use_lists.stack().value_counts()
# Out:
# Interacting with family and friends       74
# Entertainment                             72
# Learning new information                  63
# Surfing and passing time                  42
# Sharing and posting daily life            30
# Shopping                                  18
# Spiritual practice                         1
# For exchanging ideas of Stock Market       1
# News and business updates around world     1
# dtype: int64

# %%
use_lists.stack().value_counts().plot(kind='bar', figsize=(15,7), color="#61d199")
